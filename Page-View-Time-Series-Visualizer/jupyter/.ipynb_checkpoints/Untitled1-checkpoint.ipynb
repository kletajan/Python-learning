# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from pandas.plotting import register_matplotlib_converters

# %%
# Import data (Make sure to parse dates. Consider setting index column to 'date'.)
df = pd.read_csv('fcc-forum-pageviews.csv', parse_dates=['date'])

# %%
len(df)
# Out:
# 1304

# %%
# Clean data
minusdata = np.floor(len(df) * 0.025).astype(int)
df = df.drop(range(0, minusdata + 1))
df = df.drop(range(len(df) - minusdata, len(df)))
len(df)
# Out:
# 1239

# %%
df.rename(columns={'date': 'Date', 'value': 'Page Views'}, inplace=True)
df
# Out:
#            Date  Page Views
# 33   2016-06-11       16098
# 34   2016-06-12       16147
# 35   2016-06-13       17570
# 36   2016-06-14       19395
# 37   2016-06-15       18584
# ...         ...         ...
# 1299 2019-11-29      171584
# 1300 2019-11-30      141161
# 1301 2019-12-01      142918
# 1302 2019-12-02      220144
# 1303 2019-12-03      158549
#
# [1239 rows x 2 columns]

# %%
df.plot.line(x="Date", y='Page Views', title="Daily freeCodeCamp Forum Page Views 5/2016-12/2019", figsize=(15,8), ylim=(20000, 200000))
# Out:
# <AxesSubplot: title={'center': 'Daily freeCodeCamp Forum Page Views 5/2016-12/2019'}, xlabel='Date'>
